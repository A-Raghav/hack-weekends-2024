# %%
import json

# %%
docebaas_json = json.load(open("../src/data/docebosaas_with_summary.json"))
drive_training_json = json.load(open("../src/data/drive-training-session-summary-url.json"))
docs_json = json.load(open("../src/data/json_file_summary_dashboard_pdf.json"))

# %%
print(len(docebaas_json))
print(len(drive_training_json))
print(len(docs_json))
# Out:
# 13
# 7
# 13

# %%
docebaas_json[0]
# Out:
# {'url': 'https://innovacceracademy.docebosaas.com/learn/course/4/61-algorithms-pop-health-analytics;lp=63',
# ...

# %%
print(docs_json[0]['summary'])
# Out:
# Title and Type of Dashboard:
# The dashboard is titled "Attribution Management" and appears to be a healthcare or insurance-related performance dashboard.
#
# Key Metrics:
# 1. Attributed Members: 107,223 (decreased by 62.5% from previous year)
# 2. Newly Enrolled: 219 (decreased by 90.2% from previous year)
# 3. Disenrolled: 239 (decreased by 96.8% from previous year)
# 4. Deceased: 2 (decreased by 50% from previous year)
#
# Graphs and Analysis:
#
# 1. Attributed Members Trend:
# - Shows monthly trends for 2019, 2020, and 2021
# - 2019 shows a significant decline throughout the year
# - 2020 and 2021 show relatively stable but lower numbers compared to 2019
#
# 2. Attributed Members by Payer:
# - Three categories: INNO MSSP, INNO SUPER, INNO PLUS
# - INNO MSSP has the highest number of attributed members
#
# 3. Attributed Members by Enrollment Status:
# - Four categories: Aged/Non-Dual, Disabled, Aged/Dual, ESRD
# - Aged/Non-Dual has the highest number of attributed members
#
# ...

# %%
print(docs_json[1]['url'])
print(docs_json[1]['summary'])
# Out:
# https://drive.google.com/file/d/1v7Np-08gv0zZyT73IC9Yb8WMQv-tlhN2/view
# Title and Type: The dashboard is titled "Care Management" and appears to be a healthcare management analytics dashboard.
#
# Key Metrics:
# - Total Strategies: 2
# - Assigned Protocols: 176
# - Open Protocols: 126
# - Closed Protocols: 50
# - Successful Protocols: 14
# - Success Percentage: 8.0%
# - Avg Days to Complete Protocol: 88
# - Total Assessments: 86
#
# Graphs and Analysis:
#
# 1. Patients Assigned by Strategy: A donut chart shows two strategies - Pka (34.15%) and A1c (65.85%).
#
# 2. Patients Assigned by Protocol: A bar chart shows 176 patients assigned to Care Navigation.
#
# 3. Unsuccessful Protocols by Reason: A horizontal bar chart displays reasons for unsuccessful protocols, with "Unable to contact patient" being the most common (22 cases).
#
# 4. Health Coach Performance: A table shows performance metrics for different health coaches, including assigned, open, closed, and successful protocols.
#
# ...

# %%
print(drive_training_json[0]['summary'])
# Out:
# The session was structured into multiple phases, beginning with "Healthcare 101," a basic conversation about US healthcare, the various players involved, and common terminologies. The next session, "Healthcare Data 101," planned for the following day, aimed to delve into commonly used data elements and their real-world significance, focusing on terms like "allowed amount" and "multiple commodities" related to patients.
#
# The discussion then moved to Value-Based Care (VBC) in the population health management (PHM) space, which is the main focus of the attendees' work. This segment aimed to clarify what VBC entails, including its implications for analytics work, cost and utilization models, and the conversion of raw claims into inpatient visits. The session also planned to cover risk and quality aspects, real-world cost implications, network design, and the importance of identifying low-performing providers to improve healthcare outcomes and financial incentives.
#
# ...

# %%
print("\n".join(drive_training_json[0]['content'].split(".")))
# Out:
# It it
#  Yeah, thank you
#  So we try to structure it into multiple phases, right? So today we're gonna start with healthcare one on one
#  And what that essentially means is a very basic conversation around what actually is us health care, who are the different players? What are the different terminologies that you may have heard of? Not heard of even coded for but not really know the full intent of what you guys are quoting, right? That's the intent with healthcare one on one with healthcare data 101 which will happen tomorrow
#  The intent is let's dig into some of the data elements that we most commonly and most frequently use
#  And let's try to understand the significance of how those are created in the real world out there
# ...
